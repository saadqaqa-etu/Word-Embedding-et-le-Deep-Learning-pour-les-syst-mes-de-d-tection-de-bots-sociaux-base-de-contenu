# %% [markdown]
# <a href="https://colab.research.google.com/github/saadqaqa-etu/Word-Embedding-et-le-Deep-Learning-pour-les-syst-mes-de-d-tection-de-bots-sociaux-base-de-contenu/blob/main/pfa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, LSTM, Dense, Input, Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# Download NLTK stopwords
nltk.download('stopwords')

# Define preprocessing functions
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+|www\S+', '', text)

    # Remove mentions (@username) and hashtags (#)
    text = re.sub(r'@[^\s]+', '', text)
    text = re.sub(r'#', '', text)

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenization
    tokens = text.split()

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Rejoin tokens into a single string
    text = ' '.join(tokens)

    return text

json_file_path = 'drive/MyDrive/train.json'
df = pd.read_json(json_file_path)

df['tweet'] = df['tweet'].astype(str)
df['tweet'] = df['tweet'].apply(preprocess_text)

# Define parameters for tokenization and padding
max_vocabulary = 4000
max_length = 50
embedding_size = 100

# Tokenize and pad sequences
tokenizer = Tokenizer(num_words=max_vocabulary)
tokenizer.fit_on_texts(df['tweet'])
sequences = tokenizer.texts_to_sequences(df['tweet'])
Data_T = pad_sequences(sequences, maxlen=max_length)

# Split data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(Data_T, df.label, test_size=0.2501, random_state=42)

glove_file = 'drive/MyDrive/glove.twitter.27B.100d.txt'  # Replace with the path to your GloVe file
word_vectors = {}
with open(glove_file, 'r', encoding='utf-8') as file:
    for line in file:
        values = line.split()
        word = values[0]
        vector = np.array(values[1:], dtype='float32')
        word_vectors[word] = vector

vocabulary_size = max_vocabulary
embedding_dim = 100

embedding_matrix = np.zeros((vocabulary_size, embedding_dim))
for word, i in tokenizer.word_index.items():
    if i < vocabulary_size:
        embedding_vector = word_vectors.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Hyperparameter Tuning
learning_rate = 0.001  #  the learning rate
batch_size = 64  #  batch size
epochs = 50  #  the number of epochs

#  deep learning model
input_layer = Input(shape=(max_length,))
embedding_layer = Embedding(input_dim=vocabulary_size, output_dim=embedding_dim,
                            weights=[embedding_matrix], input_length=max_length, trainable=False)(input_layer)


#  Conv1D layer
conv1d_layer = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding_layer)

from keras.layers import Bidirectional, GRU, LSTM



#  BiGRU and LSTM layers
bigru_layer1 = Bidirectional(GRU(100, return_sequences=True))(conv1d_layer)
dropout1 = Dropout(0.5)(bigru_layer1)

lstm_layer1 = LSTM(100, return_sequences=True)(dropout1)
dropout2 = Dropout(0.5)(lstm_layer1)

bigru_layer2 = Bidirectional(GRU(100, return_sequences=True))(dropout2)
dropout3 = Dropout(0.5)(bigru_layer2)

lstm_layer2 = LSTM(100, return_sequences=True)(dropout3)
dropout4 = Dropout(0.5)(lstm_layer2)





#  GlobalMaxPooling1D layer
maxpooling_layer = GlobalMaxPooling1D()(dropout2)

# Dense layer for classification
output_layer = Dense(1, activation='sigmoid')(maxpooling_layer)

# Compile the model with adjusted learning rate
model = Model(inputs=input_layer, outputs=output_layer)
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['accuracy'])

# Implement cross-validation
from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for train_index, val_index in kf.split(Data_T, df.label):
    x_train, x_val = Data_T[train_index], Data_T[val_index]
    y_train, y_val = df.label[train_index], df.label[val_index]

    # Train the model
    history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_val, y_val), verbose=1)

    # Evaluate the model on the test set
    loss, accuracy = model.evaluate(x_test, y_test)
    print(f'Test loss: {loss}, Test accuracy: {accuracy}')

    # Predict on the test set
    y_pred = (model.predict(x_test) > 0.5).astype(int)

    # Calculate and display classification report
    classification_rep = classification_report(y_test, y_pred)
    print(classification_rep)
# Out:
# Epoch 1/50
# 104/104 [==============================] - 14s 86ms/step - loss: 0.6536 - accuracy: 0.6207 - val_loss: 0.6488 - val_accuracy: 0.6389
# Epoch 2/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.6250 - accuracy: 0.6430 - val_loss: 0.6462 - val_accuracy: 0.6449
# Epoch 3/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.6095 - accuracy: 0.6712 - val_loss: 0.6281 - val_accuracy: 0.6721
# Epoch 4/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.5855 - accuracy: 0.6939 - val_loss: 0.6255 - val_accuracy: 0.6630
# Epoch 5/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.5624 - accuracy: 0.7085 - val_loss: 0.6261 - val_accuracy: 0.6649
# Epoch 6/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.5225 - accuracy: 0.7413 - val_loss: 0.6186 - val_accuracy: 0.6643
# Epoch 7/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.4562 - accuracy: 0.7850 - val_loss: 0.6254 - val_accuracy: 0.6510
# Epoch 8/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.3657 - accuracy: 0.8437 - val_loss: 0.6623 - val_accuracy: 0.6401
# Epoch 9/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.2624 - accuracy: 0.8910 - val_loss: 0.6780 - val_accuracy: 0.6455
# Epoch 10/50
# 104/104 [==============================] - 8s 76ms/step - loss: 0.1952 - accuracy: 0.9182 - val_loss: 0.7035 - val_accuracy: 0.6419
# Epoch 11/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.1324 - accuracy: 0.9508 - val_loss: 0.8344 - val_accuracy: 0.6516
# Epoch 12/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.1155 - accuracy: 0.9551 - val_loss: 0.9175 - val_accuracy: 0.6280
# Epoch 13/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0858 - accuracy: 0.9663 - val_loss: 0.9550 - val_accuracy: 0.6220
# Epoch 14/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0761 - accuracy: 0.9683 - val_loss: 0.9341 - val_accuracy: 0.6383
# Epoch 15/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0754 - accuracy: 0.9715 - val_loss: 1.0302 - val_accuracy: 0.5996
# Epoch 16/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0767 - accuracy: 0.9687 - val_loss: 0.9636 - val_accuracy: 0.6286
# Epoch 17/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0465 - accuracy: 0.9819 - val_loss: 1.0168 - val_accuracy: 0.6329
# Epoch 18/50
# 104/104 [==============================] - 11s 107ms/step - loss: 0.0523 - accuracy: 0.9805 - val_loss: 1.0220 - val_accuracy: 0.6341
# Epoch 19/50
# 104/104 [==============================] - 13s 125ms/step - loss: 0.0460 - accuracy: 0.9810 - val_loss: 1.0475 - val_accuracy: 0.6202
# Epoch 20/50
# 104/104 [==============================] - 14s 132ms/step - loss: 0.0349 - accuracy: 0.9850 - val_loss: 1.0819 - val_accuracy: 0.6353
# Epoch 21/50
# 104/104 [==============================] - 14s 136ms/step - loss: 0.0623 - accuracy: 0.9745 - val_loss: 0.9945 - val_accuracy: 0.6232
# Epoch 22/50
# 104/104 [==============================] - 9s 87ms/step - loss: 0.0418 - accuracy: 0.9850 - val_loss: 1.0019 - val_accuracy: 0.6310
# Epoch 23/50
# 104/104 [==============================] - 8s 82ms/step - loss: 0.0227 - accuracy: 0.9912 - val_loss: 1.1316 - val_accuracy: 0.6443
# Epoch 24/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0283 - accuracy: 0.9885 - val_loss: 1.1951 - val_accuracy: 0.6528
# Epoch 25/50
# 104/104 [==============================] - 8s 82ms/step - loss: 0.0189 - accuracy: 0.9912 - val_loss: 1.2248 - val_accuracy: 0.6353
# Epoch 26/50
# 104/104 [==============================] - 9s 84ms/step - loss: 0.0279 - accuracy: 0.9888 - val_loss: 1.2549 - val_accuracy: 0.6335
# Epoch 27/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0473 - accuracy: 0.9829 - val_loss: 1.0451 - val_accuracy: 0.6335
# Epoch 28/50
# 104/104 [==============================] - 8s 82ms/step - loss: 0.0407 - accuracy: 0.9849 - val_loss: 1.1017 - val_accuracy: 0.6244
# Epoch 29/50
# 104/104 [==============================] - 8s 82ms/step - loss: 0.0240 - accuracy: 0.9909 - val_loss: 1.2049 - val_accuracy: 0.6431
# Epoch 30/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0305 - accuracy: 0.9869 - val_loss: 1.1782 - val_accuracy: 0.6461
# Epoch 31/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0568 - accuracy: 0.9772 - val_loss: 1.1158 - val_accuracy: 0.6492
# Epoch 32/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0443 - accuracy: 0.9828 - val_loss: 1.1142 - val_accuracy: 0.6280
# Epoch 33/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0216 - accuracy: 0.9912 - val_loss: 1.1387 - val_accuracy: 0.6335
# Epoch 34/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0196 - accuracy: 0.9914 - val_loss: 1.2117 - val_accuracy: 0.6298
# Epoch 35/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0169 - accuracy: 0.9923 - val_loss: 1.2332 - val_accuracy: 0.6292
# Epoch 36/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0127 - accuracy: 0.9937 - val_loss: 1.2866 - val_accuracy: 0.6341
# Epoch 37/50
# 104/104 [==============================] - 10s 94ms/step - loss: 0.0489 - accuracy: 0.9808 - val_loss: 1.0342 - val_accuracy: 0.6232
# Epoch 38/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 1.1621 - val_accuracy: 0.6425
# Epoch 39/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0225 - accuracy: 0.9909 - val_loss: 1.1924 - val_accuracy: 0.6504
# Epoch 40/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0178 - accuracy: 0.9924 - val_loss: 1.2298 - val_accuracy: 0.6419
# Epoch 41/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0116 - accuracy: 0.9934 - val_loss: 1.2673 - val_accuracy: 0.6498
# Epoch 42/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0117 - accuracy: 0.9941 - val_loss: 1.3159 - val_accuracy: 0.6443
# Epoch 43/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0331 - accuracy: 0.9858 - val_loss: 1.3109 - val_accuracy: 0.6298
# Epoch 44/50
# 104/104 [==============================] - 10s 99ms/step - loss: 0.0447 - accuracy: 0.9823 - val_loss: 1.1426 - val_accuracy: 0.6473
# Epoch 45/50
# 104/104 [==============================] - 10s 92ms/step - loss: 0.0251 - accuracy: 0.9899 - val_loss: 1.2111 - val_accuracy: 0.6329
# Epoch 46/50
# 104/104 [==============================] - 10s 98ms/step - loss: 0.0245 - accuracy: 0.9900 - val_loss: 1.2079 - val_accuracy: 0.6353
# Epoch 47/50
# 104/104 [==============================] - 9s 86ms/step - loss: 0.0172 - accuracy: 0.9926 - val_loss: 1.2628 - val_accuracy: 0.6552
# Epoch 48/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0208 - accuracy: 0.9920 - val_loss: 1.3329 - val_accuracy: 0.6141
# Epoch 49/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0260 - accuracy: 0.9884 - val_loss: 1.2334 - val_accuracy: 0.6467
# Epoch 50/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0431 - accuracy: 0.9820 - val_loss: 1.1101 - val_accuracy: 0.6353
# 65/65 [==============================] - 1s 18ms/step - loss: 0.2742 - accuracy: 0.9131
# Test loss: 0.2741801142692566, Test accuracy: 0.9130854606628418
# 65/65 [==============================] - 2s 17ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       898
#            1       0.91      0.94      0.92      1173
#
#     accuracy                           0.91      2071
#    macro avg       0.91      0.91      0.91      2071
# weighted avg       0.91      0.91      0.91      2071
#
# Epoch 1/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.3448 - accuracy: 0.8760 - val_loss: 0.2476 - val_accuracy: 0.9577
# Epoch 2/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.1629 - accuracy: 0.9400 - val_loss: 0.1714 - val_accuracy: 0.9764
# Epoch 3/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0763 - accuracy: 0.9763 - val_loss: 0.1261 - val_accuracy: 0.9716
# Epoch 4/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0350 - accuracy: 0.9878 - val_loss: 0.0925 - val_accuracy: 0.9764
# Epoch 5/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0207 - accuracy: 0.9915 - val_loss: 0.0889 - val_accuracy: 0.9686
# Epoch 6/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0298 - accuracy: 0.9878 - val_loss: 0.0977 - val_accuracy: 0.9668
# Epoch 7/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0172 - accuracy: 0.9937 - val_loss: 0.0881 - val_accuracy: 0.9752
# Epoch 8/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0146 - accuracy: 0.9935 - val_loss: 0.0830 - val_accuracy: 0.9674
# Epoch 9/50
# 104/104 [==============================] - 10s 92ms/step - loss: 0.0206 - accuracy: 0.9915 - val_loss: 0.0995 - val_accuracy: 0.9662
# Epoch 10/50
# 104/104 [==============================] - 12s 120ms/step - loss: 0.0495 - accuracy: 0.9808 - val_loss: 0.1532 - val_accuracy: 0.9469
# Epoch 11/50
# 104/104 [==============================] - 13s 124ms/step - loss: 0.0581 - accuracy: 0.9773 - val_loss: 0.1343 - val_accuracy: 0.9463
# Epoch 12/50
# 104/104 [==============================] - 12s 116ms/step - loss: 0.0443 - accuracy: 0.9825 - val_loss: 0.1398 - val_accuracy: 0.9499
# Epoch 13/50
# 104/104 [==============================] - 12s 114ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.1264 - val_accuracy: 0.9529
# Epoch 14/50
# 104/104 [==============================] - 12s 117ms/step - loss: 0.0126 - accuracy: 0.9941 - val_loss: 0.1117 - val_accuracy: 0.9553
# Epoch 15/50
# 104/104 [==============================] - 11s 105ms/step - loss: 0.0107 - accuracy: 0.9932 - val_loss: 0.1144 - val_accuracy: 0.9529
# Epoch 16/50
# 104/104 [==============================] - 9s 90ms/step - loss: 0.0110 - accuracy: 0.9943 - val_loss: 0.1050 - val_accuracy: 0.9577
# Epoch 17/50
# 104/104 [==============================] - 9s 86ms/step - loss: 0.0104 - accuracy: 0.9944 - val_loss: 0.1052 - val_accuracy: 0.9577
# Epoch 18/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0106 - accuracy: 0.9940 - val_loss: 0.1054 - val_accuracy: 0.9577
# Epoch 19/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0106 - accuracy: 0.9947 - val_loss: 0.1029 - val_accuracy: 0.9589
# Epoch 20/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0099 - accuracy: 0.9949 - val_loss: 0.1052 - val_accuracy: 0.9601
# Epoch 21/50
# 104/104 [==============================] - 10s 93ms/step - loss: 0.0118 - accuracy: 0.9943 - val_loss: 0.1120 - val_accuracy: 0.9541
# Epoch 22/50
# 104/104 [==============================] - 10s 96ms/step - loss: 0.0103 - accuracy: 0.9944 - val_loss: 0.1052 - val_accuracy: 0.9595
# Epoch 23/50
# 104/104 [==============================] - 10s 96ms/step - loss: 0.0103 - accuracy: 0.9938 - val_loss: 0.1012 - val_accuracy: 0.9601
# Epoch 24/50
# 104/104 [==============================] - 10s 98ms/step - loss: 0.0104 - accuracy: 0.9932 - val_loss: 0.1026 - val_accuracy: 0.9601
# Epoch 25/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0100 - accuracy: 0.9949 - val_loss: 0.1040 - val_accuracy: 0.9589
# Epoch 26/50
# 104/104 [==============================] - 9s 91ms/step - loss: 0.0096 - accuracy: 0.9949 - val_loss: 0.1052 - val_accuracy: 0.9577
# Epoch 27/50
# 104/104 [==============================] - 12s 118ms/step - loss: 0.0099 - accuracy: 0.9941 - val_loss: 0.1101 - val_accuracy: 0.9547
# Epoch 28/50
# 104/104 [==============================] - 11s 102ms/step - loss: 0.0110 - accuracy: 0.9938 - val_loss: 0.1107 - val_accuracy: 0.9595
# Epoch 29/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0745 - accuracy: 0.9764 - val_loss: 0.2886 - val_accuracy: 0.8744
# Epoch 30/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.1068 - accuracy: 0.9568 - val_loss: 0.2012 - val_accuracy: 0.9227
# Epoch 31/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0373 - accuracy: 0.9869 - val_loss: 0.1753 - val_accuracy: 0.9330
# Epoch 32/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0188 - accuracy: 0.9909 - val_loss: 0.1703 - val_accuracy: 0.9348
# Epoch 33/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0178 - accuracy: 0.9929 - val_loss: 0.1740 - val_accuracy: 0.9330
# Epoch 34/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0222 - accuracy: 0.9891 - val_loss: 0.2275 - val_accuracy: 0.9034
# Epoch 35/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0260 - accuracy: 0.9893 - val_loss: 0.2110 - val_accuracy: 0.9179
# Epoch 36/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0463 - accuracy: 0.9829 - val_loss: 0.2778 - val_accuracy: 0.8871
# Epoch 37/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0340 - accuracy: 0.9857 - val_loss: 0.1973 - val_accuracy: 0.9245
# Epoch 38/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0214 - accuracy: 0.9902 - val_loss: 0.2124 - val_accuracy: 0.9185
# Epoch 39/50
# 104/104 [==============================] - 8s 76ms/step - loss: 0.0135 - accuracy: 0.9937 - val_loss: 0.2117 - val_accuracy: 0.9209
# Epoch 40/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0106 - accuracy: 0.9947 - val_loss: 0.2104 - val_accuracy: 0.9221
# Epoch 41/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0100 - accuracy: 0.9952 - val_loss: 0.2074 - val_accuracy: 0.9221
# Epoch 42/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0097 - accuracy: 0.9949 - val_loss: 0.2074 - val_accuracy: 0.9245
# Epoch 43/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0097 - accuracy: 0.9946 - val_loss: 0.2099 - val_accuracy: 0.9233
# Epoch 44/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0100 - accuracy: 0.9941 - val_loss: 0.2096 - val_accuracy: 0.9239
# Epoch 45/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0097 - accuracy: 0.9946 - val_loss: 0.2107 - val_accuracy: 0.9233
# Epoch 46/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0097 - accuracy: 0.9941 - val_loss: 0.2090 - val_accuracy: 0.9209
# Epoch 47/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0093 - accuracy: 0.9950 - val_loss: 0.2107 - val_accuracy: 0.9233
# Epoch 48/50
# 104/104 [==============================] - 10s 100ms/step - loss: 0.0097 - accuracy: 0.9946 - val_loss: 0.2134 - val_accuracy: 0.9197
# Epoch 49/50
# 104/104 [==============================] - 10s 100ms/step - loss: 0.0092 - accuracy: 0.9947 - val_loss: 0.2144 - val_accuracy: 0.9227
# Epoch 50/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0208 - accuracy: 0.9912 - val_loss: 0.3500 - val_accuracy: 0.8665
# 65/65 [==============================] - 1s 18ms/step - loss: 0.1192 - accuracy: 0.9580
# Test loss: 0.11923956871032715, Test accuracy: 0.9579913020133972
# 65/65 [==============================] - 1s 17ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       898
#            1       0.98      0.94      0.96      1173
#
#     accuracy                           0.96      2071
#    macro avg       0.96      0.96      0.96      2071
# weighted avg       0.96      0.96      0.96      2071
#
# Epoch 1/50
# 104/104 [==============================] - 9s 84ms/step - loss: 0.1684 - accuracy: 0.9379 - val_loss: 0.1200 - val_accuracy: 0.9734
# Epoch 2/50
# 104/104 [==============================] - 10s 93ms/step - loss: 0.0462 - accuracy: 0.9840 - val_loss: 0.0618 - val_accuracy: 0.9861
# Epoch 3/50
# 104/104 [==============================] - 10s 95ms/step - loss: 0.0179 - accuracy: 0.9929 - val_loss: 0.0709 - val_accuracy: 0.9819
# Epoch 4/50
# 104/104 [==============================] - 10s 93ms/step - loss: 0.0136 - accuracy: 0.9938 - val_loss: 0.0406 - val_accuracy: 0.9903
# Epoch 5/50
# 104/104 [==============================] - 10s 98ms/step - loss: 0.0105 - accuracy: 0.9947 - val_loss: 0.0370 - val_accuracy: 0.9915
# Epoch 6/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0128 - accuracy: 0.9932 - val_loss: 0.0375 - val_accuracy: 0.9903
# Epoch 7/50
# 104/104 [==============================] - 8s 75ms/step - loss: 0.0120 - accuracy: 0.9941 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 8/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0111 - accuracy: 0.9940 - val_loss: 0.0419 - val_accuracy: 0.9867
# Epoch 9/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0097 - accuracy: 0.9952 - val_loss: 0.0378 - val_accuracy: 0.9885
# Epoch 10/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0093 - accuracy: 0.9940 - val_loss: 0.0363 - val_accuracy: 0.9885
# Epoch 11/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0092 - accuracy: 0.9950 - val_loss: 0.0358 - val_accuracy: 0.9879
# Epoch 12/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0099 - accuracy: 0.9947 - val_loss: 0.0362 - val_accuracy: 0.9873
# Epoch 13/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0094 - accuracy: 0.9952 - val_loss: 0.0357 - val_accuracy: 0.9879
# Epoch 14/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0092 - accuracy: 0.9944 - val_loss: 0.0351 - val_accuracy: 0.9891
# Epoch 15/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0093 - accuracy: 0.9952 - val_loss: 0.0360 - val_accuracy: 0.9891
# Epoch 16/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0089 - accuracy: 0.9952 - val_loss: 0.0348 - val_accuracy: 0.9885
# Epoch 17/50
# 104/104 [==============================] - 8s 76ms/step - loss: 0.0094 - accuracy: 0.9940 - val_loss: 0.0349 - val_accuracy: 0.9891
# Epoch 18/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0088 - accuracy: 0.9955 - val_loss: 0.0355 - val_accuracy: 0.9885
# Epoch 19/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0092 - accuracy: 0.9950 - val_loss: 0.0342 - val_accuracy: 0.9897
# Epoch 20/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0091 - accuracy: 0.9949 - val_loss: 0.0349 - val_accuracy: 0.9885
# Epoch 21/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0087 - accuracy: 0.9949 - val_loss: 0.0340 - val_accuracy: 0.9885
# Epoch 22/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0091 - accuracy: 0.9947 - val_loss: 0.0345 - val_accuracy: 0.9879
# Epoch 23/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0090 - accuracy: 0.9941 - val_loss: 0.0330 - val_accuracy: 0.9897
# Epoch 24/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0088 - accuracy: 0.9953 - val_loss: 0.0328 - val_accuracy: 0.9873
# Epoch 25/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0091 - accuracy: 0.9949 - val_loss: 0.0351 - val_accuracy: 0.9879
# Epoch 26/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0091 - accuracy: 0.9946 - val_loss: 0.0331 - val_accuracy: 0.9891
# Epoch 27/50
# 104/104 [==============================] - 8s 76ms/step - loss: 0.0090 - accuracy: 0.9947 - val_loss: 0.0347 - val_accuracy: 0.9885
# Epoch 28/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0090 - accuracy: 0.9953 - val_loss: 0.0334 - val_accuracy: 0.9885
# Epoch 29/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0092 - accuracy: 0.9947 - val_loss: 0.0338 - val_accuracy: 0.9885
# Epoch 30/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0090 - accuracy: 0.9943 - val_loss: 0.0327 - val_accuracy: 0.9885
# Epoch 31/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0091 - accuracy: 0.9943 - val_loss: 0.0331 - val_accuracy: 0.9885
# Epoch 32/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0090 - accuracy: 0.9950 - val_loss: 0.0320 - val_accuracy: 0.9879
# Epoch 33/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0090 - accuracy: 0.9950 - val_loss: 0.0325 - val_accuracy: 0.9885
# Epoch 34/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0090 - accuracy: 0.9946 - val_loss: 0.0341 - val_accuracy: 0.9873
# Epoch 35/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0109 - accuracy: 0.9944 - val_loss: 0.0319 - val_accuracy: 0.9903
# Epoch 36/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0141 - accuracy: 0.9937 - val_loss: 0.0751 - val_accuracy: 0.9734
# Epoch 37/50
# 104/104 [==============================] - 8s 76ms/step - loss: 0.1887 - accuracy: 0.9284 - val_loss: 0.1812 - val_accuracy: 0.9312
# Epoch 38/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0548 - accuracy: 0.9783 - val_loss: 0.1545 - val_accuracy: 0.9390
# Epoch 39/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0217 - accuracy: 0.9912 - val_loss: 0.1165 - val_accuracy: 0.9614
# Epoch 40/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0139 - accuracy: 0.9932 - val_loss: 0.1079 - val_accuracy: 0.9595
# Epoch 41/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0109 - accuracy: 0.9943 - val_loss: 0.1017 - val_accuracy: 0.9620
# Epoch 42/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0102 - accuracy: 0.9949 - val_loss: 0.1010 - val_accuracy: 0.9601
# Epoch 43/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0093 - accuracy: 0.9953 - val_loss: 0.1012 - val_accuracy: 0.9607
# Epoch 44/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0090 - accuracy: 0.9947 - val_loss: 0.1015 - val_accuracy: 0.9601
# Epoch 45/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0091 - accuracy: 0.9950 - val_loss: 0.1030 - val_accuracy: 0.9607
# Epoch 46/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0093 - accuracy: 0.9950 - val_loss: 0.1020 - val_accuracy: 0.9607
# Epoch 47/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0094 - accuracy: 0.9944 - val_loss: 0.1010 - val_accuracy: 0.9620
# Epoch 48/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0091 - accuracy: 0.9946 - val_loss: 0.1007 - val_accuracy: 0.9620
# Epoch 49/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0090 - accuracy: 0.9946 - val_loss: 0.1007 - val_accuracy: 0.9614
# Epoch 50/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0089 - accuracy: 0.9944 - val_loss: 0.1003 - val_accuracy: 0.9626
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0306 - accuracy: 0.9889
# Test loss: 0.030584074556827545, Test accuracy: 0.9888942837715149
# 65/65 [==============================] - 1s 16ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       898
#            1       0.99      0.99      0.99      1173
#
#     accuracy                           0.99      2071
#    macro avg       0.99      0.99      0.99      2071
# weighted avg       0.99      0.99      0.99      2071
#
# Epoch 1/50
# 104/104 [==============================] - 8s 82ms/step - loss: 0.1220 - accuracy: 0.9521 - val_loss: 0.0928 - val_accuracy: 0.9782
# Epoch 2/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0482 - accuracy: 0.9820 - val_loss: 0.0545 - val_accuracy: 0.9897
# Epoch 3/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0256 - accuracy: 0.9887 - val_loss: 0.0424 - val_accuracy: 0.9897
# Epoch 4/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0132 - accuracy: 0.9941 - val_loss: 0.0366 - val_accuracy: 0.9891
# Epoch 5/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0097 - accuracy: 0.9944 - val_loss: 0.0326 - val_accuracy: 0.9915
# Epoch 6/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0091 - accuracy: 0.9953 - val_loss: 0.0307 - val_accuracy: 0.9921
# Epoch 7/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0088 - accuracy: 0.9950 - val_loss: 0.0304 - val_accuracy: 0.9927
# Epoch 8/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0088 - accuracy: 0.9955 - val_loss: 0.0292 - val_accuracy: 0.9927
# Epoch 9/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0089 - accuracy: 0.9953 - val_loss: 0.0284 - val_accuracy: 0.9921
# Epoch 10/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0089 - accuracy: 0.9956 - val_loss: 0.0277 - val_accuracy: 0.9934
# Epoch 11/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0089 - accuracy: 0.9955 - val_loss: 0.0284 - val_accuracy: 0.9927
# Epoch 12/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0086 - accuracy: 0.9955 - val_loss: 0.0272 - val_accuracy: 0.9934
# Epoch 13/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0087 - accuracy: 0.9950 - val_loss: 0.0273 - val_accuracy: 0.9927
# Epoch 14/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0086 - accuracy: 0.9952 - val_loss: 0.0265 - val_accuracy: 0.9934
# Epoch 15/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0086 - accuracy: 0.9950 - val_loss: 0.0260 - val_accuracy: 0.9934
# Epoch 16/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0087 - accuracy: 0.9950 - val_loss: 0.0256 - val_accuracy: 0.9934
# Epoch 17/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0086 - accuracy: 0.9941 - val_loss: 0.0270 - val_accuracy: 0.9921
# Epoch 18/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0085 - accuracy: 0.9949 - val_loss: 0.0258 - val_accuracy: 0.9927
# Epoch 19/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0085 - accuracy: 0.9952 - val_loss: 0.0256 - val_accuracy: 0.9921
# Epoch 20/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0086 - accuracy: 0.9955 - val_loss: 0.0259 - val_accuracy: 0.9927
# Epoch 21/50
# 104/104 [==============================] - 9s 90ms/step - loss: 0.0088 - accuracy: 0.9955 - val_loss: 0.0252 - val_accuracy: 0.9934
# Epoch 22/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0084 - accuracy: 0.9952 - val_loss: 0.0253 - val_accuracy: 0.9934
# Epoch 23/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0088 - accuracy: 0.9953 - val_loss: 0.0251 - val_accuracy: 0.9934
# Epoch 24/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0086 - accuracy: 0.9947 - val_loss: 0.0251 - val_accuracy: 0.9934
# Epoch 25/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0085 - accuracy: 0.9953 - val_loss: 0.0250 - val_accuracy: 0.9934
# Epoch 26/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0087 - accuracy: 0.9947 - val_loss: 0.0251 - val_accuracy: 0.9934
# Epoch 27/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0087 - accuracy: 0.9952 - val_loss: 0.0246 - val_accuracy: 0.9927
# Epoch 28/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0084 - accuracy: 0.9953 - val_loss: 0.0266 - val_accuracy: 0.9915
# Epoch 29/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0086 - accuracy: 0.9953 - val_loss: 0.0245 - val_accuracy: 0.9927
# Epoch 30/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0086 - accuracy: 0.9941 - val_loss: 0.0254 - val_accuracy: 0.9915
# Epoch 31/50
# 104/104 [==============================] - 8s 82ms/step - loss: 0.0085 - accuracy: 0.9953 - val_loss: 0.0255 - val_accuracy: 0.9915
# Epoch 32/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0086 - accuracy: 0.9950 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 33/50
# 104/104 [==============================] - 9s 87ms/step - loss: 0.0085 - accuracy: 0.9949 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 34/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0084 - accuracy: 0.9953 - val_loss: 0.0246 - val_accuracy: 0.9921
# Epoch 35/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0083 - accuracy: 0.9955 - val_loss: 0.0257 - val_accuracy: 0.9921
# Epoch 36/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0085 - accuracy: 0.9953 - val_loss: 0.0244 - val_accuracy: 0.9915
# Epoch 37/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0085 - accuracy: 0.9950 - val_loss: 0.0242 - val_accuracy: 0.9915
# Epoch 38/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0086 - accuracy: 0.9950 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 39/50
# 104/104 [==============================] - 9s 84ms/step - loss: 0.0086 - accuracy: 0.9955 - val_loss: 0.0244 - val_accuracy: 0.9915
# Epoch 40/50
# 104/104 [==============================] - 8s 82ms/step - loss: 0.0092 - accuracy: 0.9950 - val_loss: 0.0298 - val_accuracy: 0.9921
# Epoch 41/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0089 - accuracy: 0.9944 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 42/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0084 - accuracy: 0.9937 - val_loss: 0.0259 - val_accuracy: 0.9921
# Epoch 43/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0086 - accuracy: 0.9955 - val_loss: 0.0272 - val_accuracy: 0.9903
# Epoch 44/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0119 - accuracy: 0.9940 - val_loss: 0.4534 - val_accuracy: 0.8610
# Epoch 45/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.1576 - accuracy: 0.9425 - val_loss: 0.1420 - val_accuracy: 0.9577
# Epoch 46/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0314 - accuracy: 0.9882 - val_loss: 0.1170 - val_accuracy: 0.9619
# Epoch 47/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0161 - accuracy: 0.9935 - val_loss: 0.0955 - val_accuracy: 0.9674
# Epoch 48/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0100 - accuracy: 0.9955 - val_loss: 0.0885 - val_accuracy: 0.9656
# Epoch 49/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0090 - accuracy: 0.9953 - val_loss: 0.0848 - val_accuracy: 0.9686
# Epoch 50/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0088 - accuracy: 0.9955 - val_loss: 0.0843 - val_accuracy: 0.9680
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0325 - accuracy: 0.9903
# Test loss: 0.0325050950050354, Test accuracy: 0.9903428554534912
# 65/65 [==============================] - 1s 17ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       898
#            1       0.99      0.99      0.99      1173
#
#     accuracy                           0.99      2071
#    macro avg       0.99      0.99      0.99      2071
# weighted avg       0.99      0.99      0.99      2071
#
# Epoch 1/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0711 - accuracy: 0.9728 - val_loss: 0.0641 - val_accuracy: 0.9867
# Epoch 2/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0338 - accuracy: 0.9870 - val_loss: 0.0365 - val_accuracy: 0.9927
# Epoch 3/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0132 - accuracy: 0.9947 - val_loss: 0.0352 - val_accuracy: 0.9915
# Epoch 4/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0093 - accuracy: 0.9956 - val_loss: 0.0273 - val_accuracy: 0.9915
# Epoch 5/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0087 - accuracy: 0.9958 - val_loss: 0.0263 - val_accuracy: 0.9915
# Epoch 6/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0085 - accuracy: 0.9958 - val_loss: 0.0247 - val_accuracy: 0.9915
# Epoch 7/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0083 - accuracy: 0.9958 - val_loss: 0.0247 - val_accuracy: 0.9915
# Epoch 8/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0082 - accuracy: 0.9956 - val_loss: 0.0240 - val_accuracy: 0.9915
# Epoch 9/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0081 - accuracy: 0.9958 - val_loss: 0.0237 - val_accuracy: 0.9915
# Epoch 10/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0080 - accuracy: 0.9958 - val_loss: 0.0238 - val_accuracy: 0.9915
# Epoch 11/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0082 - accuracy: 0.9958 - val_loss: 0.0230 - val_accuracy: 0.9915
# Epoch 12/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0081 - accuracy: 0.9958 - val_loss: 0.0234 - val_accuracy: 0.9915
# Epoch 13/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0234 - val_accuracy: 0.9915
# Epoch 14/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0080 - accuracy: 0.9953 - val_loss: 0.0236 - val_accuracy: 0.9915
# Epoch 15/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0081 - accuracy: 0.9958 - val_loss: 0.0238 - val_accuracy: 0.9915
# Epoch 16/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0080 - accuracy: 0.9958 - val_loss: 0.0242 - val_accuracy: 0.9915
# Epoch 17/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0246 - val_accuracy: 0.9915
# Epoch 18/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0080 - accuracy: 0.9955 - val_loss: 0.0248 - val_accuracy: 0.9915
# Epoch 19/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0079 - accuracy: 0.9953 - val_loss: 0.0247 - val_accuracy: 0.9915
# Epoch 20/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0080 - accuracy: 0.9958 - val_loss: 0.0248 - val_accuracy: 0.9915
# Epoch 21/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0245 - val_accuracy: 0.9915
# Epoch 22/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0249 - val_accuracy: 0.9915
# Epoch 23/50
# 104/104 [==============================] - 8s 78ms/step - loss: 0.0079 - accuracy: 0.9956 - val_loss: 0.0247 - val_accuracy: 0.9921
# Epoch 24/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0246 - val_accuracy: 0.9915
# Epoch 25/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 26/50
# 104/104 [==============================] - 9s 83ms/step - loss: 0.0080 - accuracy: 0.9953 - val_loss: 0.0249 - val_accuracy: 0.9921
# Epoch 27/50
# 104/104 [==============================] - 9s 82ms/step - loss: 0.0080 - accuracy: 0.9958 - val_loss: 0.0246 - val_accuracy: 0.9921
# Epoch 28/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0252 - val_accuracy: 0.9921
# Epoch 29/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0080 - accuracy: 0.9958 - val_loss: 0.0252 - val_accuracy: 0.9921
# Epoch 30/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0079 - accuracy: 0.9953 - val_loss: 0.0251 - val_accuracy: 0.9921
# Epoch 31/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0077 - accuracy: 0.9958 - val_loss: 0.0252 - val_accuracy: 0.9921
# Epoch 32/50
# 104/104 [==============================] - 8s 79ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0249 - val_accuracy: 0.9921
# Epoch 33/50
# 104/104 [==============================] - 8s 77ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0253 - val_accuracy: 0.9921
# Epoch 34/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0078 - accuracy: 0.9956 - val_loss: 0.0257 - val_accuracy: 0.9921
# Epoch 35/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0253 - val_accuracy: 0.9921
# Epoch 36/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0080 - accuracy: 0.9953 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 37/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 38/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0079 - accuracy: 0.9952 - val_loss: 0.0247 - val_accuracy: 0.9921
# Epoch 39/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0079 - accuracy: 0.9961 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 40/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0081 - accuracy: 0.9950 - val_loss: 0.0257 - val_accuracy: 0.9921
# Epoch 41/50
# 104/104 [==============================] - 9s 85ms/step - loss: 0.0080 - accuracy: 0.9950 - val_loss: 0.0249 - val_accuracy: 0.9921
# Epoch 42/50
# 104/104 [==============================] - 13s 127ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 43/50
# 104/104 [==============================] - 14s 137ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0253 - val_accuracy: 0.9921
# Epoch 44/50
# 104/104 [==============================] - 15s 142ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0256 - val_accuracy: 0.9921
# Epoch 45/50
# 104/104 [==============================] - 15s 148ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0257 - val_accuracy: 0.9921
# Epoch 46/50
# 104/104 [==============================] - 15s 142ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0256 - val_accuracy: 0.9921
# Epoch 47/50
# 104/104 [==============================] - 10s 93ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0258 - val_accuracy: 0.9921
# Epoch 48/50
# 104/104 [==============================] - 8s 80ms/step - loss: 0.0079 - accuracy: 0.9956 - val_loss: 0.0259 - val_accuracy: 0.9921
# Epoch 49/50
# 104/104 [==============================] - 10s 93ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0258 - val_accuracy: 0.9921
# Epoch 50/50
# 104/104 [==============================] - 8s 81ms/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.0267 - val_accuracy: 0.9921
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0123 - accuracy: 0.9957
# Test loss: 0.012266449630260468, Test accuracy: 0.995654284954071
# 65/65 [==============================] - 1s 18ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       898
#            1       0.99      1.00      1.00      1173
#
#     accuracy                           1.00      2071
#    macro avg       1.00      1.00      1.00      2071
# weighted avg       1.00      1.00      1.00      2071

# %%
from keras.utils import plot_model

plot_model(model, to_file='model_visualization.png', show_shapes=True)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

false_positive_rate = conf_matrix[0, 1] / (conf_matrix[0, 0] + conf_matrix[0, 1])
print("False Positive Rate:", false_positive_rate)

specificity = conf_matrix[1, 1] / (conf_matrix[1, 0] + conf_matrix[1, 1])
print("Specificity (True Negative Rate):", specificity)

false_negative_rate = conf_matrix[1, 0] / (conf_matrix[1, 0] + conf_matrix[1, 1])
print("False Negative Rate:", false_negative_rate)
# Out:
# False Positive Rate: 0.0066815144766146995
# Specificity (True Negative Rate): 0.9974424552429667
# False Negative Rate: 0.0025575447570332483

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt



precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

metrics = ['Precision', 'Recall', 'F1-Score']
values = [precision, recall, f1]

plt.figure(figsize=(8, 6))
plt.bar(metrics, values, color=['blue', 'green', 'orange'])
plt.ylim(0, 1)
plt.title('Precision, Recall, and F1-Score')
print(precision, recall, f1)

plt.xlabel('Metrics')
plt.ylabel('Score')
plt.show()
# Out:
# 0.9948979591836735 0.9974424552429667 0.996168582375479

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from keras.utils import plot_model

# Visualize the model and save it to a file
plot_model(model, to_file='your_model_visualization.png', show_shapes=True)
import matplotlib.pyplot as plt

# Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
